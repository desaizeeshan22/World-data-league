# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder

# %%
parking_data=pd.read_csv("merged_parking.csv")

# %%
parking_data.head()
# Out:
#    Unnamed: 0  Block    Street   EntryDate  Bylaw  Section Status  \
# 0           0   1400  Kingsway  2017-08-23   2849     17.1     IS
# 1           1   1400  KINGSWAY  2018-07-25   2849     17.1     IS
# 2           2   1400  KINGSWAY  2019-07-03   2849  19.1(G)     VA
# 3           3   1400  KINGSWAY  2018-01-08   2849     17.1     IS
# 4           4   1400  KINGSWAY  2018-01-04   2849     17.1     IS
#
#                                       InfractionText    Year         HBLOCK  \
# 0  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2017.0  1400 KINGSWAY
# 1  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2018.0  1400 KINGSWAY
# 2  STOP ON A LANE WITHIN AN AREA 1.5M FROM EITHER...  2019.0  1400 KINGSWAY
# 3  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2018.0  1400 KINGSWAY
# 4  STOP AT A PLACE WHERE A TRAFFIC SIGN PROHIBITS...  2018.0  1400 KINGSWAY
#
#   STREETUSE                                    coord_1  \
# 0  Arterial  [-123.07609868345955, 49.250113144142205]
# 1  Arterial  [-123.07609868345955, 49.250113144142205]
# 2  Arterial  [-123.07609868345955, 49.250113144142205]
# 3  Arterial  [-123.07609868345955, 49.250113144142205]
# 4  Arterial  [-123.07609868345955, 49.250113144142205]
#
#                                      coord_2
# 0  [-123.07335078330377, 49.248972158836736]
# 1  [-123.07335078330377, 49.248972158836736]
# 2  [-123.07335078330377, 49.248972158836736]
# 3  [-123.07335078330377, 49.248972158836736]
# 4  [-123.07335078330377, 49.248972158836736]

# %%
data = ['InfractionText','Street','Status','HBLOCK','STREETUSE']

# %%
for column in data:
    ord_enc = OrdinalEncoder()
    parking_data[column] = ord_enc.fit_transform(parking_data[[column]])

# %%
parking_data['co-ordinates'] = parking_data[parking_data.columns[11:]].apply(lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# %%
X = parking_data['EntryDate']
Y = parking_data['InfractionText']
Y1 = parking_data['co-ordinates']

# %%
new_data = [X,Y,Y1]

# %%
prediction_df = pd.DataFrame(new_data).T

# %%
from datetime import datetime

# %%
prediction_df["EntryDate"]=prediction_df["EntryDate"].apply(lambda x:datetime.strptime(x,'%Y-%m-%d'))

# %%
series_value = prediction_df.values

# %%
total_tickets = prediction_df.groupby(prediction_df["EntryDate"])['InfractionText'].count()
total_tickets.describe()
# Out:
# count    578.000000
# mean      61.378893
# std       77.623475
# min        1.000000
# 25%       10.000000
# 50%       32.000000
# 75%       87.000000
# max      491.000000
# Name: InfractionText, dtype: float64

# %%
total_tickets= total_tickets[0:365]
total_tickets.describe()
# Out:
# count    365.000000
# mean      56.430137
# std       65.658488
# min        1.000000
# 25%       10.000000
# 50%       30.000000
# 75%       85.000000
# max      353.000000
# Name: InfractionText, dtype: float64

# %%
total_tickets.plot()
# Out:
# <AxesSubplot:xlabel='EntryDate'>

# %%
total_tickets_mean = total_tickets.rolling(window=12).mean()

# %%
total_tickets_mean=total_tickets_mean.dropna()

# %%
total_tickets_mean.plot()
# total_tickets_mean
# Out:
# <AxesSubplot:xlabel='EntryDate'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(x=total_tickets_mean, extrapolate_trend='freq', period=int(len(total_tickets_mean)/2))

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.plot(decomposition.seasonal)
plt.xlabel('Date')
plt.ylabel('Total number of tickets')
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.plot(decomposition.trend)
plt.xlabel('Date')
plt.ylabel('Total number of tickets')
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.plot(decomposition.resid)
plt.xlabel('Date')
plt.ylabel('Total number of tickets')
plt.show()

# %% [markdown]
# <h2>BASE LINE MODEL</h2>
#
#
#
# The previous value is the best reflection of the future value series(t+1)

# %%
total_coordinates=prediction_df.groupby(['EntryDate','co-ordinates','InfractionText'])['InfractionText'].count()

# %%
baseline_df = pd.concat([total_coordinates,total_coordinates.shift(1)],axis=1)

# %%
baseline_df.columns =['Actual_ticket_count','Forecast_ticket_count']

# %%
baseline_df.head()
# Out:
#                                                                               Actual_ticket_count  \
# EntryDate  co-ordinates                                       InfractionText
# 2017-01-03 [-123.05969934101618, 49.28480845599848],[-123.... 24.0                              1
# 2017-01-05 [-123.11786601656868, 49.28009446774853],[-123.... 14.0                              1
#            [-123.11848760269254, 49.278412209736196],[-123... 14.0                              1
#            [-123.11897220754433, 49.27664157636647],[-123.... 14.0                              2
#            [-123.11952591787794, 49.27699993083262],[-123.... 14.0                              1
#
#                                                                               Forecast_ticket_count
# EntryDate  co-ordinates                                       InfractionText
# 2017-01-03 [-123.05969934101618, 49.28480845599848],[-123.... 24.0                              NaN
# 2017-01-05 [-123.11786601656868, 49.28009446774853],[-123.... 14.0                              1.0
#            [-123.11848760269254, 49.278412209736196],[-123... 14.0                              1.0
#            [-123.11897220754433, 49.27664157636647],[-123.... 14.0                              1.0
#            [-123.11952591787794, 49.27699993083262],[-123.... 14.0                              2.0

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %% [markdown]
# remove the first nan value

# %%
baseline_df = baseline_df[1:] 
# baseline_df.tail()

# %%
baseline_mse = mean_squared_error(baseline_df.Actual_ticket_count,baseline_df.Forecast_ticket_count)

# %%
baseline_mse
# Out:
# 0.6131076751636718

# %%
np.sqrt(baseline_mse)
# Out:
# 0.7830119253010593

# %% [markdown]
# <h2>ARIMA MODEL</h2>
#
# Autoregressive(p)- The current value is correlated with the previous value and the previous value is the best reflection of the current value.
#
# integrated(d)
#
# moving average (q)- smoothing moving the error and noise from the data

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %% [markdown]
# Plot_acf is to indentify parameter Q
# Arima(p,d,q)

# %%
plot_acf(total_coordinates)

# %%
plot_pacf(total_coordinates)

# %% [markdown]
# p = 2,3 d =0,q = 3,4

# %%
total_coordinates.size
# Out:
# 28717

# %%
from sklearn.model_selection import train_test_split

# %%
train = total_coordinates[0:28000]
test = total_coordinates[28000:28717]

# %%
test.size
# Out:
# 717

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(train,order = (5,0,4)).fit()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
model.aic
# Out:
# 50115.56657494317

# %%
forecast = model.forecast(steps =717)[0]

# %%
forecast
# Out:
# array([1.64027137, 1.50133677, 1.44456592, 1.4037148 , 1.37162103,
#        1.35949971, 1.35377793, 1.33953762, 1.33055615, 1.33292563,
#        1.32876018, 1.31789839, 1.3173523 , 1.32022262, 1.31218736,
#        1.3054955 , 1.30938708, 1.30811717, 1.29869228, 1.2977794 ,
#        1.30179817, 1.29570323, 1.28889373, 1.29252013, 1.29295072,
#        1.28451327, 1.28285711, 1.28745223, 1.28307203, 1.27618436,
#        1.27926755, 1.28106347, 1.27366526, 1.27125733, 1.27608675,
#        1.27328716, 1.26644912, 1.26882148, 1.27168272, 1.26537609,
#        1.26227017, 1.26704784, 1.2656819 , 1.2590345 , 1.26059439,
#        1.26423698, 1.25905492, 1.25534615, 1.25983646, 1.25974235,
#        1.25342662, 1.25412938, 1.25828789, 1.25423935, 1.25005194,
#        1.25406824, 1.25507171, 1.24921937, 1.24906913, 1.25349997,
#        1.25056789, 1.24604425, 1.24944698, 1.25136495, 1.24609133,
#        1.24513298, 1.24961755, 1.24775881, 1.24304996, 1.24574408,
#        1.24838907, 1.24378801, 1.24209917, 1.24644654, 1.24559353,
#        1.24085072, 1.24278261, 1.2459674 , 1.24210799, 1.23979123,
#        1.24384015, 1.24390358, 1.23927127, 1.24042482, 1.2439673 ,
#        1.24089218, 1.23806753, 1.24168772, 1.24256027, 1.23817034,
#        1.23856266, 1.24229027, 1.24001541, 1.23681338, 1.23990586,
#        1.24146646, 1.23743381, 1.2371104 , 1.24086414, 1.23937987,
#        1.23593496, 1.23843159, 1.24055005, 1.23696935, 1.235999  ,
#        1.23963689, 1.23890987, 1.23535481, 1.23721703, 1.23975867,
#        1.23670235, 1.23517194, 1.23857165, 1.23854766, 1.23500844,
#        1.23622521, 1.23905544, 1.23657279, 1.23458205, 1.23764278,
#        1.23825014, 1.23484184, 1.23542698, 1.23841548, 1.23653273,
#        1.2341892 , 1.23683277, 1.23798607, 1.23480955, 1.23479857,
#        1.23782308, 1.2365444 , 1.23395866, 1.23612972, 1.23773382,
#        1.23487335, 1.23431991, 1.23726943, 1.23657856, 1.23385992,
#        1.23552551, 1.2374795 , 1.23500118, 1.23397329, 1.23675064,
#        1.23661329, 1.23386591, 1.23501425, 1.23721534, 1.23516641,
#        1.23374258, 1.23626628, 1.2366328 , 1.23395247, 1.23459128,
#        1.23693835, 1.23534719, 1.23361259, 1.23581808, 1.23662657,
#        1.23409805, 1.23425226, 1.23664914, 1.23552599, 1.23356878,
#        1.23540895, 1.23658843, 1.23428351, 1.23399275, 1.23635094,
#        1.23568919, 1.23359712, 1.23504218, 1.23651585, 1.23449206,
#        1.23380774, 1.23604872, 1.23582668, 1.23368402, 1.23472087,
#        1.23640925, 1.23470911, 1.23369158, 1.23574849, 1.23593149,
#        1.23381645, 1.23444748, 1.23627138, 1.23492236, 1.23363786,
#        1.23545667, 1.23599951, 1.23398203, 1.23422352, 1.2361067 ,
#        1.23512166, 1.23363947, 1.23517961, 1.23602905, 1.23416918,
#        1.23404942, 1.23592092, 1.23529901, 1.23368876, 1.23492321,
#        1.23602054, 1.23436727, 1.23392441, 1.23572046, 1.23544846,
#        1.23377766, 1.23469258, 1.23597618, 1.23456676, 1.23384655,
#        1.23551212, 1.23556602, 1.23389791, 1.23449185, 1.23589957,
#        1.23475936, 1.23381281, 1.23530262, 1.23564949, 1.23404127,
#        1.23432405, 1.23579537, 1.23493806, 1.2338192 , 1.23509838,
#        1.23569834, 1.23419972, 1.23419099, 1.23566899, 1.23509723,
#        1.23386094, 1.23490523, 1.23571345, 1.23436569, 1.23409333,
#        1.23552626, 1.23523262, 1.23393265, 1.2347282 , 1.23569695,
#        1.2345322 , 1.23403056, 1.23537317, 1.23534134, 1.23402855,
#        1.23457144, 1.235652  , 1.23469305, 1.23400115, 1.2352156 ,
#        1.23542179, 1.23414268, 1.23443809, 1.2355825 , 1.23484289,
#        1.23400263, 1.23505913, 1.23547359, 1.23426908, 1.23433028,
#        1.23549293, 1.23497734, 1.23403178, 1.2349088 , 1.23549745,
#        1.23440202, 1.23424908, 1.23538808, 1.23509304, 1.23408479,
#        1.23476906, 1.23549502, 1.23453611, 1.23419461, 1.23527287,
#        1.23518761, 1.2341574 , 1.23464358, 1.23546874, 1.23466649,
#        1.23416609, 1.23515213, 1.23525968, 1.23424515, 1.23453523,
#        1.23542167, 1.2347889 , 1.23416194, 1.23503045, 1.23530879,
#        1.23434347, 1.23444603, 1.23535733, 1.23489979, 1.23417992,
#        1.23491206, 1.23533537, 1.2344479 , 1.23437718, 1.23527952,
#        1.23499637, 1.23421724, 1.23480068, 1.23534057, 1.2345542 ,
#        1.23432908, 1.23519214, 1.23507661, 1.23427074, 1.23469943,
#        1.23532621, 1.23465848, 1.23430138, 1.23509909, 1.23513925,
#        1.234337  , 1.23461081, 1.23529459, 1.2347573 , 1.23429306,
#        1.23500408, 1.23518377, 1.23441249, 1.23453667, 1.23524842,
#        1.23484774, 1.23430256, 1.23491056, 1.23521033, 1.2344937 ,
#        1.23447816, 1.23519066, 1.23492745, 1.23432782, 1.23482159,
#        1.23521971, 1.23457727, 1.2344358 , 1.23512438, 1.23499469,
#        1.23436648, 1.2347398 , 1.23521318, 1.23466009, 1.23440951,
#        1.23505267, 1.2350483 , 1.2344159 , 1.23466732, 1.23519248,
#        1.23473934, 1.23439867, 1.2349785 , 1.23508772, 1.23447337,
#        1.23460576, 1.23515966, 1.23481263, 1.23440217, 1.23490467,
#        1.23511292, 1.23453611, 1.23455621, 1.23511699, 1.23487799,
#        1.23441852, 1.23483369, 1.23512438, 1.23460146, 1.23451923,
#        1.23506687, 1.2349339 , 1.23444595, 1.23476772, 1.235123  ,
#        1.23466691, 1.23449489, 1.23501175, 1.23497933, 1.23448244,
#        1.23470858, 1.23511005, 1.23473019, 1.23448284, 1.23495398,
#        1.2350137 , 1.23452587, 1.23465764, 1.23508706, 1.23478932,
#        1.23448232, 1.23489583, 1.23503687, 1.23457409, 1.23461589,
#        1.23505579, 1.23484265, 1.23449226, 1.23483932, 1.23504911,
#        1.23462496, 1.2345839 , 1.23501809, 1.23488888, 1.23451132,
#        1.23478625, 1.23505102, 1.2346765 , 1.23456184, 1.23497587,
#        1.23492709, 1.23453797, 1.23473813, 1.23504352, 1.23472684,
#        1.23454953, 1.23493102, 1.23495673, 1.23457058, 1.23469615,
#        1.23502776, 1.23477436, 1.23454647, 1.23488534, 1.23497757,
#        1.23460745, 1.23466117, 1.23500507, 1.2348177 , 1.23455189,
#        1.23484049, 1.23498975, 1.2346469 , 1.23463374, 1.23497688,
#        1.23485575, 1.23456479, 1.23479792, 1.23499365, 1.23468732,
#        1.23461408, 1.2349447 , 1.23488769, 1.23458403, 1.2347589 ,
#        1.23498993, 1.23472724, 1.23460214, 1.23491001, 1.23491301,
#        1.23460832, 1.23472444, 1.23497944, 1.23476531, 1.2345976 ,
#        1.23487424, 1.23493146, 1.23463637, 1.23469528, 1.23496318,
#        1.2348004 , 1.2345999 , 1.23483874, 1.23494306, 1.23466683,
#        1.23467194, 1.23494226, 1.23483158, 1.23460833, 1.2348047 ,
#        1.23494804, 1.23469843, 1.23465467, 1.23491785, 1.23485814,
#        1.23462201, 1.23477316, 1.23494688, 1.23472998, 1.23464349,
#        1.23489112, 1.23487961, 1.23463997, 1.23474498, 1.23494019,
#        1.23476038, 1.2346382 , 1.23486322, 1.23489573, 1.23466119,
#        1.2347208 , 1.23492872, 1.23478869, 1.23463843, 1.23483521,
#        1.23490644, 1.23468461, 1.23470108, 1.23491334, 1.23481415,
#        1.23464366, 1.23480807, 1.2349119 , 1.23470923, 1.23468608,
#        1.23489493, 1.23483613, 1.23465321, 1.23478267, 1.2349124 ,
#        1.23473407, 1.23467587, 1.23487442, 1.23485421, 1.23466636,
#        1.2347597 , 1.23490841, 1.23475827, 1.23467034, 1.23485272,
#        1.23486813, 1.23468231, 1.23473974, 1.23490049, 1.23478105,
#        1.23466925, 1.2348307 , 1.23487782, 1.23470024, 1.23472318,
#        1.23488929, 1.23480175, 1.23467221, 1.23480913, 1.23488333,
#        1.23471934, 1.23471028, 1.23487549, 1.23481986, 1.23467873,
#        1.23478873, 1.23488487, 1.23473885, 1.23470114, 1.23485983,
#        1.23483499, 1.23468825, 1.23477009, 1.23488277, 1.23475805,
#        1.2346957 , 1.23484303, 1.23484692, 1.23470016, 1.23475368,
#        1.23487745, 1.23477631, 1.23469382, 1.23482576, 1.23485553,
#        1.23471381, 1.23473986, 1.23486939, 1.23479309, 1.23469521,
#        1.23480868, 1.23486083, 1.23472858, 1.23472885, 1.23485912,
#        1.23480795, 1.23469952, 1.23479235, 1.23486296, 1.23474385,
#        1.23472078, 1.23484723, 1.23482055, 1.23470632, 1.23477726,
#        1.23486215, 1.23475904, 1.23471565, 1.23483426, 1.23483068,
#        1.23471514, 1.23476383, 1.23485871, 1.23477363, 1.23471334,
#        1.23482078, 1.23483822, 1.23472549, 1.23475235, 1.23485299,
#        1.23478718, 1.23471368, 1.23480729, 1.23484316, 1.23473686,
#        1.23474303, 1.23484542, 1.23479932, 1.2347164 , 1.23479426,
#        1.23484558, 1.23474876, 1.234736  , 1.23483643, 1.23480976,
#        1.23472118, 1.23478209, 1.23484562, 1.23476074, 1.23473128,
#        1.23482647, 1.23481831, 1.23472765, 1.23477113, 1.23484352,
#        1.23477236, 1.23472881, 1.23481598, 1.23482485, 1.23473545,
#        1.23476164, 1.23483954, 1.23478327, 1.23472847, 1.23480536,
#        1.23482934, 1.23474416, 1.23475381, 1.23483401, 1.23479316,
#        1.23473006, 1.23479499, 1.23483182, 1.23475341, 1.23474775,
#        1.23482726, 1.23480177, 1.23473334, 1.23478522, 1.23483241,
#        1.23476282, 1.23474349, 1.23481965, 1.23480894, 1.23473805,
#        1.23477631, 1.23483125, 1.23477206, 1.23474103, 1.23481151,
#        1.23481455, 1.23474388, 1.2347685 , 1.23482855, 1.23478081,
#        1.23474026, 1.23480318, 1.23481856, 1.23475053, 1.23476195,
#        1.23482456, 1.23478883, 1.23474107, 1.23479496, 1.23482098,
#        1.23475768, 1.23475677, 1.23481953, 1.2347959 , 1.23474326,
#        1.23478712, 1.23482188, 1.23476506, 1.234753  , 1.23481373,
#        1.23480188, 1.23474664, 1.23477991, 1.23482137, 1.23477237,
#        1.23475064, 1.23480744, 1.23480666, 1.23475097, 1.23477351,
#        1.2348196 , 1.23477937, 1.23474965, 1.23480093, 1.23481019,
#        1.23475601, 1.23476806, 1.23481676, 1.23478585, 1.23474992,
#        1.23479443, 1.23481246, 1.23476153, 1.23476366, 1.23481304,
#        1.23479164, 1.23475133, 1.23478818, 1.23481352, 1.23476729,
#        1.23476037, 1.23480865])

# %%
np.sqrt(mean_squared_error(test,forecast))
# Out:
# 0.676437229383252
