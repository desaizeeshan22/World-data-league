# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
loans_df = pd.read_csv("bike_loans_merged.csv")

# %%
loans_df.head()
# Out:
#    Unnamed: 0  Loan_ID  User_ID   Bike_Tag_ID     Loan_start_date_time  \
# 0           0  6501462    18701  000017B00743  2017-06-21 14:22:11.000
# 1           1  6501318    41811  000017AFF83C  2017-06-21 14:07:18.000
# 2           2  6501489    96620  000017AFFB6F  2017-06-21 14:25:11.000
# 3           3  6501001    16055  0000182A3B7B  2017-06-21 13:35:52.000
# 4           4  6501421     6431  000017AFE810  2017-06-21 14:17:56.000
#
#        Loan_stop_date_time  Origin_loan_station_ID  \
# 0  2017-06-21 14:38:29.000                       8
# 1  2017-06-21 14:39:06.000                      56
# 2  2017-06-21 14:39:07.000                      36
# 3  2017-06-21 14:39:22.000                       8
# 4  2017-06-21 14:39:26.000                      56
#
#    Position_number_bike_origin  Return_loan_station_ID  \
# 0                            1                    43.0
# 1                            6                    54.0
# 2                           25                     9.0
# 3                            1                     9.0
# 4                           14                    54.0
#
#    Position_number_bike_destination  ... origin_station_short_name Origin_Lat  \
# 0                               1.0  ...                       EST   6,253349
# 1                               NaN  ...                       PCL    6,23055
# 2                              13.0  ...                       CIS   6,246078
# 3                               6.0  ...                       EST   6,253349
# 4                               NaN  ...                       PCL    6,23055
#
#    Origin_Lon Origin_isManual Return_station_description return_station_slots  \
# 0  -75,587692             1.0          Cisneros - Unaula                 33.0
# 1  -75,574373             0.0                  Primavera                 40.0
# 2  -75,571561             0.0                   San Juan                 14.0
# 3  -75,587692             1.0                   San Juan                 14.0
# 4  -75,574373             0.0                  Primavera                 40.0
#
#    return_station_short_name Return_Lat  Return_Lon Return_isManual
# 0                        LOM   6,250576  -75,574814             1.0
# 1                        RTN     6,2253  -75,572449             1.0
# 2                        SJU   6,249014  -75,588585             0.0
# 3                        SJU   6,249014  -75,588585             0.0
# 4                        RTN     6,2253  -75,572449             1.0
#
# [5 rows x 23 columns]

# %%
loans_df.dtypes
# Out:
# Unnamed: 0                            int64
# Loan_ID                               int64
# User_ID                               int64
# Bike_Tag_ID                          object
# Loan_start_date_time                 object
# Loan_stop_date_time                  object
# Origin_loan_station_ID                int64
# Position_number_bike_origin           int64
# Return_loan_station_ID              float64
# Position_number_bike_destination    float64
# operator_presence                    object
# Origin_station_description           object
# origin_station_slots                float64
# origin_station_short_name            object
# Origin_Lat                           object
# Origin_Lon                           object
# Origin_isManual                     float64
# Return_station_description           object
# return_station_slots                float64
# return_station_short_name            object
# Return_Lat                           object
# Return_Lon                           object
# Return_isManual                     float64
# dtype: object

# %%
highest_rental_station = loans_df.groupby(["Origin_station_description"])['Origin_loan_station_ID'].count()
highest_rental_station_df= pd.DataFrame(highest_rental_station)#Convert the series into dataframe
highest_rental_station_df.columns =['Total Loans']#rename the columns for better understanding
highest_rental_station_df
# Out:
#                             Total Loans
# Origin_station_description
# Auxiliar Metro Envigado            2859
# Aves María                         7580
# Bahía Ciclovia                      629
# Batallón                         138365
# Biblioteca Sabaneta                4080
# ...                                 ...
# Villa Carlota                    150362
# Villa Paula                        1349
# Villas de vallejuelos              3131
# Viva envigado                      7080
# Área Metropolitana               190519
#
# [107 rows x 1 columns]

# %%
import plotly.express as px

# %%
highest_rental_station_df.sort_values(by=['Total Loans'], inplace=True,ascending=False)
highest_rental_station_df
# Out:
#                             Total Loans
# Origin_station_description
# Estadio                          791863
# Suramericana                     673281
# Floresta                         515569
# Ruta N                           469246
# Universidad                      442668
# ...                                 ...
# Metróplus Cami                      590
# Los Naranjos                        587
# Las Vegas 69 Sur                    564
# Puerta La 77 Sur                    389
# Puente pan de Queso II              159
#
# [107 rows x 1 columns]

# %% [markdown]
# Display only the top 10 stations with the highest loan rate

# %%
fig = px.bar(highest_rental_station_df.head(10), orientation='h', width=800, height=500)
fig.show()
# From looking at the graph its clear that the stations:
# 1)Estadio
# 2)Suramericana
# 3)Floresta
# These are the top 3 stations with the highest loan rate
# Out:
# <div>                            <div id="36b9ac01-d28c-4111-b1ba-bb0660ade0f9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36b9ac01-d28c-4111-b1ba-bb0660ade0f9")) {                    Plotly.newPlot(                        "36b9ac01-d28c-4111-b1ba-bb0660ade0f9",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Total Loans<br>value=%{x}<br>Origin_station_description=%{y}<extra></extra>", "legendgroup": "Total Loans", "marker": {"color": "#636efa"}, "name": "Total Loans", "offsetgroup": "Total Loans", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [791863, 673281, 515569, 469246, 442668, 394525, 388293, 374627, 374460, 370623], "xaxis": "x", "y": ["Estadio", "Suramericana", "Floresta", "Ruta N", "Universidad", "Industriales Metropl\u00fas", "Rosales", "Museo de Antioquia", "Moravia", "UPB"], "yaxis": "y"}],                        {"barmode": "relative", "height": 500, "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.666666666666666 ...

# %%
highest_return_station = loans_df.groupby(["Return_station_description"])['Return_loan_station_ID'].count()
highest_return_station_df= pd.DataFrame(highest_return_station)#Convert the series into dataframe
highest_return_station_df.columns =['Total Loans']#rename the columns for better understanding
highest_return_station_df
# Out:
#                             Total Loans
# Return_station_description
# Auxiliar Metro Envigado            2875
# Aves María                         7513
# Bahía Ciclovia                      679
# Batallón                         132902
# Biblioteca Sabaneta                3455
# ...                                 ...
# Villa Carlota                    168854
# Villa Paula                        1070
# Villas de vallejuelos              4506
# Viva envigado                      8158
# Área Metropolitana               135340
#
# [107 rows x 1 columns]

# %%
highest_return_station_df.sort_values(by=['Total Loans'], inplace = True,ascending=False)
highest_return_station_df
# Out:
#                             Total Loans
# Return_station_description
# Estadio                          733697
# Suramericana                     638557
# Floresta                         551572
# Ruta N                           486504
# Universidad                      434903
# ...                                 ...
# Metróplus Cami                      574
# Las Vegas 69 Sur                    571
# Los Naranjos                        497
# Puerta La 77 Sur                    391
# Puente pan de Queso II              153
#
# [107 rows x 1 columns]

# %%
fig = px.bar(highest_return_station_df.head(10), orientation='h', width=800, height=500)
fig.show()
# From looking at the graph its clear that the stations:
# 1)Estadio
# 2)Suramericana
# 3)Floresta
# These are the top 3 stations with the highest return rate
# Out:
# <div>                            <div id="647889ed-2c15-4e68-8228-ade2ce629a5c" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("647889ed-2c15-4e68-8228-ade2ce629a5c")) {                    Plotly.newPlot(                        "647889ed-2c15-4e68-8228-ade2ce629a5c",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Total Loans<br>value=%{x}<br>Return_station_description=%{y}<extra></extra>", "legendgroup": "Total Loans", "marker": {"color": "#636efa"}, "name": "Total Loans", "offsetgroup": "Total Loans", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [733697, 638557, 551572, 486504, 434903, 427249, 423064, 412808, 405288, 372646], "xaxis": "x", "y": ["Estadio", "Suramericana", "Floresta", "Ruta N", "Universidad", "Moravia", "Museo de Antioquia", "Parque de Las Luces I", "UPB", "Universidad Nacional"], "yaxis": "y"}],                        {"barmode": "relative", "height": 500, "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.66666666 ...

# %% [markdown]
# Conclusion: We will focus on these top 3 stations to improve the bike sharing

# %% [markdown]
# Estadio station analysis

# %%
estadio_station = loans_df[loans_df['Origin_station_description']=='Estadio']
estadio_station
# Out:
#           Unnamed: 0   Loan_ID  User_ID   Bike_Tag_ID  \
# 0                  0   6501462    18701  000017B00743
# 3                  3   6501001    16055  0000182A3B7B
# 36                36   6501564   100017  000017AFED4F
# 37                37   6501558   100363  000017B027C8
# 38                38   6501623   100144  000017AFF8F5
# ...              ...       ...      ...           ...
# 14225267    14225267  17262170    43203  000069740076
# 14225289    14225289  17272933    10829  00003859E3E2
# 14225305    14225305  17272533   117758  0000EEE03133
# 14225348    14225348  17272944    95019  00002C8463C7
# 14225354    14225354  17272787   120899  0000B5C6F1E2
#
#              Loan_start_date_time      Loan_stop_date_time  \
# 0         2017-06-21 14:22:11.000  2017-06-21 14:38:29.000
# 3         2017-06-21 13:35:52.000  2017-06-21 14:39:22.000
# 36        2017-06-21 14:32:59.000  2017-06-21 14:45:49.000
# 37        2017-06-21 14:32:32.000  2017-06-21 14:45:52.000
# 38        2017-06-21 14:39:27.000  2017-06-21 14:46:08.000
# ...                           ...                      ...
# 14225267  2021-04-19 13:53:10.000  2021-04-20 20:50:42.000
# 14225289  2021-04-20 18:52:59.000  2021-04-20 19:26:24.000
# 14225305  2021-04-20 18:16:25.000  2021-04-20 18:57:25.000
# 14225348  2021-04-20 18:54:23.000  2021-04-20 19:49:08.000
# 14225354  2021-04-20 18:39:06.000  2021-04-20 19:51:17.000
#
#           Origin_loan_station_ID  Position_number_bike_origin  \
# 0                              8                            1
# 3                              8                            1
# 36                             8                            1
# 37                             8                            1
# 38                             8                            1
# ...                          ...                          ...
# 14225267                       8                            1
# 14225289                       8                            1
# 14225305                       8                            1
# 14225348                       8                            1
# 14225354                       8                            1
#
#           Return_loan_station_ID  Position_number_bike_destination  ...  \
# 0                           43.0                               1.0  ...
# 3                            9.0                               6.0  ...
# 36                          22.0                               8.0  ...
# 37                          22.0                               6.0  ...
# 38                          10.0                               1.0  ...
# ...                          ...                               ...  ...
# 14225267                    83.0                               NaN  ...
# 14225289                   100.0                              19.0  ...
# 14225305                     7.0                               1.0  ...
# 14225348                     8.0                               1.0  ...
# 14225354                     2.0                               1.0  ...
#
#          origin_station_short_name Origin_Lat  Origin_Lon Origin_isManual  \
# 0                              EST   6,253349  -75,587692             1.0
# 3                              EST   6,253349  -75,587692             1.0
# 36                             EST   6,253349  -75,587692             1.0
# 37                             EST   6,253349  -75,587692             1.0
# 38                             EST   6,253349  -75,587692             1.0
# ...                            ...        ...         ...             ...
# 14225267                       EST   6,253349  -75,587692             1.0
# 14225289                       EST   6,253349  -75,587692             1.0
# 14225305                       EST   6,253349  -75,587692             1.0
# 14225348                       EST   6,253349  -75,587692             1.0
# 14225354                       EST   6,253349  -75,587692             1.0
#
#          Return_station_description return_station_slots  \
# 0                 Cisneros - Unaula                 33.0
# 3                          San Juan                 14.0
# 36        Primer Parque de Laureles                 32.0
# 37        Primer Parque de Laureles                 32.0
# 38                              UPB                 12.0
# ...                             ...                  ...
# 14225267                        NaN                  NaN
# 14225289                   Bulerias                 40.0
# 14225305               Suramericana                 20.0
# 14225348                    Estadio                 20.0
# 14225354                Universidad                 33.0
#
#           return_station_short_name  Return_Lat    Return_Lon Return_isManual
# 0                               LOM    6,250576    -75,574814             1.0
# 3                               SJU    6,249014    -75,588585             0.0
# 36                              LAU     6,24597    -75,593812             0.0
# 37                              LAU     6,24597    -75,593812             0.0
# 38                              UPB    6,244998    -75,589188             1.0
# ...                             ...         ...           ...             ...
# 14225267                        NaN         NaN           NaN             NaN
# 14225289                         BU  6,23857801  -75,59041411             0.0
# 14225305                        SUR    6,253003    -75,582687             1.0
# 14225348                        EST    6,253349    -75,587692             1.0
# 14225354                        UNI    6,269267      -75,5653             1.0
#
# [791863 rows x 23 columns]

# %%
from datetime import datetime

# %%
estadio_station['Loan_start_date_time'] = pd.to_datetime(estadio_station['Loan_start_date_time']).dt.date
yearly_loans = estadio_station.groupby(["Loan_start_date_time"])["Origin_loan_station_ID"].count()
yearly_loans
# Out:
# <ipython-input-84-44c0135d0f05>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Loan_start_date_time
# 2014-06-03    131
# 2014-06-04    104
# 2014-06-05    121
# 2014-06-06    110
# 2014-06-09    109
#              ...
# 2021-04-13    390
# 2021-04-14    352
# 2021-04-15    338
# 2021-04-19    379
# 2021-04-20    371
# Name: Origin_loan_station_ID, Length: 1820, dtype: int64

# %%
estadio_station_df= pd.DataFrame(yearly_loans)#Convert the series into dataframe
estadio_station_df.columns =['Total Loans']#rename the columns for better understanding
estadio_station_df
# Out:
#                       Total Loans
# Loan_start_date_time
# 2014-06-03                    131
# 2014-06-04                    104
# 2014-06-05                    121
# 2014-06-06                    110
# 2014-06-09                    109
# ...                           ...
# 2021-04-13                    390
# 2021-04-14                    352
# 2021-04-15                    338
# 2021-04-19                    379
# 2021-04-20                    371
#
# [1820 rows x 1 columns]

# %%
fig = px.line(estadio_station_df, width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="2a4cd583-b2ff-4114-baff-faf0594c1d92" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a4cd583-b2ff-4114-baff-faf0594c1d92")) {                    Plotly.newPlot(                        "2a4cd583-b2ff-4114-baff-faf0594c1d92",                        [{"hovertemplate": "variable=Total Loans<br>Loan_start_date_time=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Loans", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Total Loans", "showlegend": true, "type": "scattergl", "x": ["2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-16", "2014-06-17", "2014-06-18", "2014-06-19", "2014-06-20", "2014-06-24", "2014-06-25", "2014-06-26", "2014-06-27", "2014-07-01", "2014-07-02", "2014-07-03", "2014-07-04", "2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-08", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-08", "2014-09-09", "2014-09-10", "2014-09-11", "2014-09-12", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-22", "2014-09-23", "2014-09-24", "2014-09-25", "2014-09-26", "2014-09-29", "2014-09-30", "2014-10-01", "2014-10-02", "2014-10-03", "2014-10-06", "2014-10-07", "2014-10-08", "2014-10-09", "2014-10-10", "2014-10-14", "2014-10-15", "2014-10-16", "2014-10-17", "2014-10-20", "2014-10-21", "2014-10-22", "2014-10-23", "2014-10-24", "2014-10-27", "2014-10-28", "2014-10-29", "2014-10-30", "2014-10-31", "2014-11-04", "2014-11-05", "2014-11-06", "2014-11-07", "2014-11-10", "2014-11-11", "2014-11-12", "2014-11-13", "2014-11-14", "2014-11-18", "2014-11-19", "2014-11-20", "2014-11-21", "2014-11-24", "2014-11-25", "2014-11-26", "2014-11-27", "2014-11-28", "2014-12-01", "2014-12-02", "2014-12-03", "2014-12-04", "2014-12-05", "2014-12-09", "2014-12-10", "2014-12-11", "2014-12-12", "2014-12-15", "2014-12-16", "2014-12-17", "2014-12-18", "2014-12-19", "2014-12-22", "2014-12-23", "2014-12-24", "2014-12-26", "2014-12-29", "2014-12-30", "2014-12-31", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-11" ...

# %%
Suramericana_station = loans_df[loans_df['Origin_station_description']=='Suramericana']
Suramericana_station
# Out:
#           Unnamed: 0   Loan_ID  User_ID   Bike_Tag_ID  \
# 49                49   6501649    98491  000017AFF6AE
# 55                55   6501615    38897  000017B03F86
# 59                59   6501678    10720  000017AFBB83
# 67                67   6501735    92099  000017B05430
# 98                98   6501534    11100  000017B00515
# ...              ...       ...      ...           ...
# 14225203    14225203  17269958   149725  000044028DC7
# 14225254    14225254  17271489    46467  0000D3D23E33
# 14225321    14225321  17272663   152651  0000768D79E2
# 14225343    14225343  17272918     4353  0000F3EC9DE2
# 14225349    14225349  17272848   151414  000005A822D9
#
#              Loan_start_date_time      Loan_stop_date_time  \
# 49        2017-06-21 14:41:52.000  2017-06-21 14:47:32.000
# 55        2017-06-21 14:38:31.000  2017-06-21 14:49:18.000
# 59        2017-06-21 14:44:04.000  2017-06-21 14:50:23.000
# 67        2017-06-21 14:51:08.000  2017-06-21 14:51:16.000
# 98        2017-06-21 14:30:40.000  2017-06-21 14:44:27.000
# ...                           ...                      ...
# 14225203  2021-04-20 14:33:40.000  2021-04-20 20:14:05.000
# 14225254  2021-04-20 16:59:39.000  2021-04-20 18:45:32.000
# 14225321  2021-04-20 18:26:01.000  2021-04-20 20:34:53.000
# 14225343  2021-04-20 18:52:01.000  2021-04-20 19:16:05.000
# 14225349  2021-04-20 18:46:11.000  2021-04-20 20:58:49.000
#
#           Origin_loan_station_ID  Position_number_bike_origin  \
# 49                             7                            1
# 55                             7                            1
# 59                             7                            1
# 67                             7                            1
# 98                             7                            1
# ...                          ...                          ...
# 14225203                       7                            1
# 14225254                       7                            1
# 14225321                       7                            1
# 14225343                       7                            1
# 14225349                       7                            1
#
#           Return_loan_station_ID  Position_number_bike_destination  ...  \
# 49                           9.0                               2.0  ...
# 55                          36.0                               2.0  ...
# 59                           8.0                               1.0  ...
# 67                           7.0                               1.0  ...
# 98                           7.0                               1.0  ...
# ...                          ...                               ...  ...
# 14225203                    66.0                               1.0  ...
# 14225254                     8.0                               1.0  ...
# 14225321                    42.0                              31.0  ...
# 14225343                     7.0                               1.0  ...
# 14225349                    11.0                               4.0  ...
#
#          origin_station_short_name Origin_Lat  Origin_Lon Origin_isManual  \
# 49                             SUR   6,253003  -75,582687             1.0
# 55                             SUR   6,253003  -75,582687             1.0
# 59                             SUR   6,253003  -75,582687             1.0
# 67                             SUR   6,253003  -75,582687             1.0
# 98                             SUR   6,253003  -75,582687             1.0
# ...                            ...        ...         ...             ...
# 14225203                       SUR   6,253003  -75,582687             1.0
# 14225254                       SUR   6,253003  -75,582687             1.0
# 14225321                       SUR   6,253003  -75,582687             1.0
# 14225343                       SUR   6,253003  -75,582687             1.0
# 14225349                       SUR   6,253003  -75,582687             1.0
#
#          Return_station_description return_station_slots  \
# 49                         San Juan                 14.0
# 55            Parque de Las Luces I                 28.0
# 59                          Estadio                 20.0
# 67                     Suramericana                 20.0
# 98                     Suramericana                 20.0
# ...                             ...                  ...
# 14225203     Industriales Metroplús                 20.0
# 14225254                    Estadio                 20.0
# 14225321             Santa Teresita                 32.0
# 14225343               Suramericana                 20.0
# 14225349                Los Colores                 22.0
#
#           return_station_short_name Return_Lat  Return_Lon Return_isManual
# 49                              SJU   6,249014  -75,588585             0.0
# 55                              CIS   6,246078  -75,571561             0.0
# 59                              EST   6,253349  -75,587692             1.0
# 67                              SUR   6,253003  -75,582687             1.0
# 98                              SUR   6,253003  -75,582687             1.0
# ...                             ...        ...         ...             ...
# 14225203                        IMP   6,231406  -75,577222             1.0
# 14225254                        EST   6,253349  -75,587692             1.0
# 14225321                        STL   6,242021  -75,596746             0.0
# 14225343                        SUR   6,253003  -75,582687             1.0
# 14225349                        COL   6,260004  -75,585136             0.0
#
# [673281 rows x 23 columns]

# %%
Suramericana_station['Loan_start_date_time'] = pd.to_datetime(Suramericana_station['Loan_start_date_time']).dt.date
Suramericana_station_yearly_loans = Suramericana_station.groupby(["Loan_start_date_time"])["Origin_loan_station_ID"].count()
Suramericana_station_yearly_loans
# Out:
# <ipython-input-92-36742eab84e5>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Loan_start_date_time
# 2014-06-03    190
# 2014-06-04    164
# 2014-06-05    192
# 2014-06-06    215
# 2014-06-09    155
#              ...
# 2021-04-13    264
# 2021-04-14    288
# 2021-04-15    257
# 2021-04-19    274
# 2021-04-20    261
# Name: Origin_loan_station_ID, Length: 1823, dtype: int64

# %%
Suramericana_station_df= pd.DataFrame(Suramericana_station_yearly_loans)#Convert the series into dataframe
Suramericana_station_df.columns =['Total Loans']#rename the columns for better understanding
Suramericana_station_df
# Out:
#                       Total Loans
# Loan_start_date_time
# 2014-06-03                    190
# 2014-06-04                    164
# 2014-06-05                    192
# 2014-06-06                    215
# 2014-06-09                    155
# ...                           ...
# 2021-04-13                    264
# 2021-04-14                    288
# 2021-04-15                    257
# 2021-04-19                    274
# 2021-04-20                    261
#
# [1823 rows x 1 columns]

# %%
fig = px.line(Suramericana_station_df, width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="35bd44ca-3563-4b7d-a496-01778bb3608f" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35bd44ca-3563-4b7d-a496-01778bb3608f")) {                    Plotly.newPlot(                        "35bd44ca-3563-4b7d-a496-01778bb3608f",                        [{"hovertemplate": "variable=Total Loans<br>Loan_start_date_time=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Loans", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Total Loans", "showlegend": true, "type": "scattergl", "x": ["2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-16", "2014-06-17", "2014-06-18", "2014-06-19", "2014-06-20", "2014-06-24", "2014-06-25", "2014-06-26", "2014-06-27", "2014-07-01", "2014-07-02", "2014-07-03", "2014-07-04", "2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-08", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-08", "2014-09-09", "2014-09-10", "2014-09-11", "2014-09-12", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-22", "2014-09-23", "2014-09-24", "2014-09-25", "2014-09-26", "2014-09-29", "2014-09-30", "2014-10-01", "2014-10-02", "2014-10-03", "2014-10-06", "2014-10-07", "2014-10-08", "2014-10-09", "2014-10-10", "2014-10-14", "2014-10-15", "2014-10-16", "2014-10-17", "2014-10-20", "2014-10-21", "2014-10-22", "2014-10-23", "2014-10-24", "2014-10-27", "2014-10-28", "2014-10-29", "2014-10-30", "2014-10-31", "2014-11-04", "2014-11-05", "2014-11-06", "2014-11-07", "2014-11-10", "2014-11-11", "2014-11-12", "2014-11-13", "2014-11-14", "2014-11-18", "2014-11-19", "2014-11-20", "2014-11-21", "2014-11-24", "2014-11-25", "2014-11-26", "2014-11-27", "2014-11-28", "2014-12-01", "2014-12-02", "2014-12-03", "2014-12-04", "2014-12-05", "2014-12-09", "2014-12-10", "2014-12-11", "2014-12-12", "2014-12-15", "2014-12-16", "2014-12-17", "2014-12-18", "2014-12-19", "2014-12-22", "2014-12-23", "2014-12-24", "2014-12-26", "2014-12-29", "2014-12-30", "2014-12-31", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-11" ...

# %%
Floresta_station = loans_df[loans_df['Origin_station_description']=='Floresta']
Floresta_station
# Out:
#           Unnamed: 0   Loan_ID  User_ID   Bike_Tag_ID  \
# 75                75   6501082    76569  000017AFF4D9
# 78                78   6501434    29312  000017B00171
# 96                96   6501098    40941  000017B02BA2
# 194              194   6501390    98943  000017B0084C
# 273              273   6501777    29883  000017AFF0CD
# ...              ...       ...      ...           ...
# 14225266    14225266  17272998   150732  0000726191E2
# 14225271    14225271  17271903   108690  0000FCC6B8E2
# 14225298    14225298  17272275   157777  00006A3190C7
# 14225299    14225299  17272270   157818  00009FF71215
# 14225317    14225317  17272952   119683  0000FB0871E2
#
#              Loan_start_date_time      Loan_stop_date_time  \
# 75        2017-06-21 13:44:08.000  2017-06-21 14:52:33.000
# 78        2017-06-21 14:19:18.000  2017-06-21 14:52:47.000
# 96        2017-06-21 13:45:30.000  2017-06-21 14:44:22.000
# 194       2017-06-21 14:15:26.000  2017-06-21 14:58:27.000
# 273       2017-06-21 14:55:11.000  2017-06-21 15:07:35.000
# ...                           ...                      ...
# 14225266  2021-04-20 19:53:17.000  2021-04-20 20:22:08.000
# 14225271  2021-04-20 17:26:09.000  2021-04-20 20:56:09.000
# 14225298  2021-04-20 17:53:30.000  2021-04-20 18:55:45.000
# 14225299  2021-04-20 17:53:10.000  2021-04-20 18:57:50.000
# 14225317  2021-04-20 18:55:34.000  2021-04-20 19:40:58.000
#
#           Origin_loan_station_ID  Position_number_bike_origin  \
# 75                            12                            1
# 78                            12                            1
# 96                            12                            1
# 194                           12                            1
# 273                           12                            1
# ...                          ...                          ...
# 14225266                      12                            1
# 14225271                      12                            1
# 14225298                      12                            1
# 14225299                      12                            1
# 14225317                      12                            1
#
#           Return_loan_station_ID  Position_number_bike_destination  ...  \
# 75                          48.0                              17.0  ...
# 78                          36.0                               2.0  ...
# 96                          16.0                               NaN  ...
# 194                          8.0                               1.0  ...
# 273                         10.0                               1.0  ...
# ...                          ...                               ...  ...
# 14225266                     7.0                               1.0  ...
# 14225271                    22.0                               NaN  ...
# 14225298                    49.0                              24.0  ...
# 14225299                    49.0                              12.0  ...
# 14225317                     1.0                               1.0  ...
#
#          origin_station_short_name Origin_Lat  Origin_Lon Origin_isManual  \
# 75                             FLO   6,258628  -75,597366             1.0
# 78                             FLO   6,258628  -75,597366             1.0
# 96                             FLO   6,258628  -75,597366             1.0
# 194                            FLO   6,258628  -75,597366             1.0
# 273                            FLO   6,258628  -75,597366             1.0
# ...                            ...        ...         ...             ...
# 14225266                       FLO   6,258628  -75,597366             1.0
# 14225271                       FLO   6,258628  -75,597366             1.0
# 14225298                       FLO   6,258628  -75,597366             1.0
# 14225299                       FLO   6,258628  -75,597366             1.0
# 14225317                       FLO   6,258628  -75,597366             1.0
#
#          Return_station_description return_station_slots  \
# 75                         Batallón                 14.0
# 78            Parque de Las Luces I                 28.0
# 96                              NaN                  NaN
# 194                         Estadio                 20.0
# 273                             UPB                 12.0
# ...                             ...                  ...
# 14225266               Suramericana                 20.0
# 14225271  Primer Parque de Laureles                 32.0
# 14225298            Pedro Nel Gómez                 26.0
# 14225299            Pedro Nel Gómez                 26.0
# 14225317                    Moravia                 15.0
#
#           return_station_short_name Return_Lat  Return_Lon Return_isManual
# 75                              P4B   6,262189  -75,595039             0.0
# 78                              CIS   6,246078  -75,571561             0.0
# 96                              NaN        NaN         NaN             NaN
# 194                             EST   6,253349  -75,587692             1.0
# 273                             UPB   6,244998  -75,589188             1.0
# ...                             ...        ...         ...             ...
# 14225266                        SUR   6,253003  -75,582687             1.0
# 14225271                        LAU    6,24597  -75,593812             0.0
# 14225298                        NTB   6,246906  -75,596625             0.0
# 14225299                        NTB   6,246906  -75,596625             0.0
# 14225317                        MRV   6,276585  -75,564804             1.0
#
# [515569 rows x 23 columns]

# %%
Floresta_station['Loan_start_date_time'] = pd.to_datetime(Floresta_station['Loan_start_date_time']).dt.date
Floresta_station_yearly_loans = Floresta_station.groupby(["Loan_start_date_time"])["Origin_loan_station_ID"].count()
Floresta_station_yearly_loans
# Out:
# <ipython-input-96-a1bdb62612f5>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Loan_start_date_time
# 2014-06-03     79
# 2014-06-04     80
# 2014-06-05     78
# 2014-06-06     81
# 2014-06-09     82
#              ...
# 2021-04-13    282
# 2021-04-14    251
# 2021-04-15    269
# 2021-04-19    303
# 2021-04-20    271
# Name: Origin_loan_station_ID, Length: 1816, dtype: int64

# %%
Floresta_station_df= pd.DataFrame(Floresta_station_yearly_loans)#Convert the series into dataframe
Floresta_station_df.columns =['Total Loans']#rename the columns for better understanding
Floresta_station_df
# Out:
#                       Total Loans
# Loan_start_date_time
# 2014-06-03                     79
# 2014-06-04                     80
# 2014-06-05                     78
# 2014-06-06                     81
# 2014-06-09                     82
# ...                           ...
# 2021-04-13                    282
# 2021-04-14                    251
# 2021-04-15                    269
# 2021-04-19                    303
# 2021-04-20                    271
#
# [1816 rows x 1 columns]

# %%
fig = px.line(Floresta_station_df, width=800, height=500)
fig.show()
# Out:
# <div>                            <div id="cc55779f-844a-4991-9397-85405055a35b" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc55779f-844a-4991-9397-85405055a35b")) {                    Plotly.newPlot(                        "cc55779f-844a-4991-9397-85405055a35b",                        [{"hovertemplate": "variable=Total Loans<br>Loan_start_date_time=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total Loans", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Total Loans", "showlegend": true, "type": "scattergl", "x": ["2014-06-03", "2014-06-04", "2014-06-05", "2014-06-06", "2014-06-09", "2014-06-10", "2014-06-11", "2014-06-12", "2014-06-13", "2014-06-16", "2014-06-17", "2014-06-18", "2014-06-19", "2014-06-20", "2014-06-24", "2014-06-25", "2014-06-26", "2014-06-27", "2014-07-01", "2014-07-02", "2014-07-03", "2014-07-04", "2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-08", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-08", "2014-09-09", "2014-09-10", "2014-09-11", "2014-09-12", "2014-09-15", "2014-09-16", "2014-09-17", "2014-09-18", "2014-09-19", "2014-09-22", "2014-09-23", "2014-09-24", "2014-09-25", "2014-09-26", "2014-09-29", "2014-09-30", "2014-10-01", "2014-10-02", "2014-10-03", "2014-10-06", "2014-10-07", "2014-10-08", "2014-10-09", "2014-10-10", "2014-10-14", "2014-10-15", "2014-10-16", "2014-10-17", "2014-10-20", "2014-10-21", "2014-10-22", "2014-10-23", "2014-10-24", "2014-10-27", "2014-10-28", "2014-10-29", "2014-10-30", "2014-10-31", "2014-11-04", "2014-11-05", "2014-11-06", "2014-11-07", "2014-11-10", "2014-11-11", "2014-11-12", "2014-11-13", "2014-11-14", "2014-11-18", "2014-11-19", "2014-11-20", "2014-11-21", "2014-11-24", "2014-11-25", "2014-11-26", "2014-11-27", "2014-11-28", "2014-12-01", "2014-12-02", "2014-12-03", "2014-12-04", "2014-12-05", "2014-12-09", "2014-12-10", "2014-12-11", "2014-12-12", "2014-12-15", "2014-12-16", "2014-12-17", "2014-12-18", "2014-12-19", "2014-12-22", "2014-12-23", "2014-12-24", "2014-12-26", "2014-12-29", "2014-12-30", "2014-12-31", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-11" ...
